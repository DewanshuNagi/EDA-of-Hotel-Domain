# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("fact_bookings.csv")
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.describe
# Out:
# <bound method NDFrame.describe of                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# ...

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date = pd.read_csv("dim_date.csv")
df_room = pd.read_csv("dim_rooms.csv")
df_agg_bookings = pd.read_csv("fact_aggregated_bookings.csv")
df_hotels = pd.read_csv("dim_hotels.csv")

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.city.unique()
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Bangalore'], dtype=object)

# %%
df_room.shape
# Out:
# (4, 2)

# %%
df_room.head(4)
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_room.room_class.unique()
# Out:
# array(['Standard', 'Elite', 'Premium', 'Presidential'], dtype=object)

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_new_bookings = df_bookings[df_bookings.no_guests>=0]
df_new_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 2            9100000              9100
# 4              10920             10920
# 5               9100              9100

# %%
df_new_bookings.shape
# Out:
# (134578, 12)

# %%
df_new_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_new_bookings.revenue_generated.max() , df_new_bookings.revenue_generated.min()
# Out:
# (np.int64(28560000), np.int64(6500))

# %%
avg, std = df_new_bookings.revenue_generated.mean() , df_new_bookings.revenue_generated.std()

# %%
avg , std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3*std

# %%
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
df_new1_bookings = df_new_bookings[df_new_bookings.revenue_generated<higher_limit]
df_new1_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920
# 5               9100              9100
# 6               9100              3640

# %%
df_new1_bookings.shape
# Out:
# (134573, 12)

# %%
df_new1_bookings.revenue_realized.max() , df_new1_bookings.revenue_realized.min()
# Out:
# (np.int64(45220), np.int64(2600))

# %%
avg , std = df_new1_bookings.revenue_realized.mean() , df_new1_bookings.revenue_realized.std()

# %%
avg , std
# Out:
# (np.float64(12695.983585117372), np.float64(6927.791692242814))

# %%
higher_limit = avg + 3*std

# %%
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_new2_bookings = df_new1_bookings[df_new1_bookings.revenue_generated>higher_limit]

# %%
df_new2_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 153     May012216559RT417        16559     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134469   Jul312219562RT47        19562    10/7/2022      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_new2_bookings.revenue_realized.describe()
# Out:
# count     1728.000000
# mean     32195.785880
# std      10248.918379
# min      13680.000000
# 25%      34200.000000
# 50%      35530.000000
# 75%      38760.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_new2_bookings[df_new2_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count     1728.000000
# mean     32195.785880
# std      10248.918379
# min      13680.000000
# 25%      34200.000000
# 50%      35530.000000
# 75%      38760.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
32195 + 3*10248
# Out:
# 62939

# %%
df_new2_bookings.isnull().sum()
# Out:
# booking_id             0
# property_id            0
# booking_date           0
# check_in_date          0
# checkout_date          0
# no_guests              0
# room_category          0
# booking_platform       0
# ratings_given        977
# booking_status         0
# revenue_generated      0
# revenue_realized       0
# dtype: int64

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings['successful_bookings'] / df_agg_bookings['capacity']
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#        occ_pct
# 0     0.833333
# ...

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x:round(x*100 , 2))

# %%
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    58.224247
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df_room
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_agg_bookings, df_room, left_on='room_category', right_on='room_id')
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard

# %%
df.drop("room_id" , axis=1 , inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %%
df.groupby("room_class")["occ_pct"].mean()
# Out:
# room_class
# Elite           58.040278
# Premium         58.028213
# Presidential    59.300461
# Standard        58.224247
# Name: occ_pct, dtype: float64

# %%
df.groupby("room_class")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='room_class'>

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df1 = pd.merge(df , df_hotels , on="property_id")
df1.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore
# 3   157.89   Standard   Atliq Grands    Luxury     Mumbai

# %%
df1.groupby("city")["occ_pct"].mean()
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.936305
# Name: occ_pct, dtype: float64

# %%
df1.groupby("city")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_date.head(4)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday

# %%
df2 = pd.merge(df1 , df_date , left_on="check_in_date" , right_on="date")
df2.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
#
#    occ_pct room_class property_name  category       city       date  mmm yy  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  10-May-22  May 22
# 1    63.33   Standard    Atliq City  Business  Hyderabad  10-May-22  May 22
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  10-May-22  May 22
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  10-May-22  May 22
#
#   week no  day_type
# 0    W 20  weekeday
# 1    W 20  weekeday
# 2    W 20  weekeday
# 3    W 20  weekeday

# %%
df2.drop("date" , axis=1 , inplace=True)
df2.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
#
#    occ_pct room_class property_name  category       city  mmm yy week no  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  May 22    W 20
# 1    63.33   Standard    Atliq City  Business  Hyderabad  May 22    W 20
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  May 22    W 20
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday
# 3  weekeday

# %%
df2.groupby("day_type")["occ_pct"].mean()
# Out:
# day_type
# weekeday    50.903780
# weekend     72.393432
# Name: occ_pct, dtype: float64

# %%
df2["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df2[df2["mmm yy"]=="Jun 22"]
df_june_22.head(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
#
#       occ_pct room_class  property_name  category       city  mmm yy week no  \
# 2200    66.67   Standard  Atliq Exotica    Luxury     Mumbai  Jun 22    W 24
# 2201    63.33   Standard      Atliq Bay    Luxury  Bangalore  Jun 22    W 24
# 2202    56.67   Standard   Atliq Palace  Business  Bangalore  Jun 22    W 24
# 2203    47.37   Standard   Atliq Grands    Luxury     Mumbai  Jun 22    W 24
#
#       day_type
# 2200  weekeday
# 2201  weekeday
# 2202  weekeday
# 2203  weekeday

# %%
df_june_22.groupby("city")["occ_pct"].mean().sort_values()
# Out:
# city
# Bangalore    56.578552
# Mumbai       58.382560
# Hyderabad    58.458075
# Delhi        62.474286
# Name: occ_pct, dtype: float64

# %%
df_august = pd.read_csv("new_data_august.csv")
df_august.head(4)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df2.shape
# Out:
# (6500, 13)

# %%
df_new = pd.concat([df2 , df_august] , axis=0 , ignore_index=True)
df_new.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        17558     31-Jul-22           RT4                    3       6.0
# 6498        19563     31-Jul-22           RT4                    3       6.0
# 6499        17561     31-Jul-22           RT4                    3       4.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city  mmm yy  \
# ...

# %%
df_new.shape
# Out:
# (6507, 14)

# %%
df_new.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
#
#    occ_pct room_class property_name  category       city  mmm yy week no  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  May 22    W 20
# 1    63.33   Standard    Atliq City  Business  Hyderabad  May 22    W 20
# 2    60.00   Standard     Atliq Bay    Luxury  Bangalore  May 22    W 20
# 3    53.33   Standard  Atliq Palace  Business  Bangalore  May 22    W 20
#
#    day_type  occ%
# 0  weekeday   NaN
# 1  weekeday   NaN
# 2  weekeday   NaN
# 3  weekeday   NaN

# %%
df_new["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22', 'Aug-22'], dtype=object)

# %%
df_new2_bookings.head(4)
# Out:
#             booking_id  property_id booking_date check_in_date checkout_date  \
# 137   May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
# 139   May012216559RT43        16559     1/5/2022      1/5/2022      2/5/2022
# 143   May012216559RT47        16559     28-04-22      1/5/2022      3/5/2022
# 149  May012216559RT413        16559     24-04-22      1/5/2022      7/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 137        4.0           RT4           others            NaN    Checked Out
# 139        6.0           RT4         tripster            3.0    Checked Out
# 143        3.0           RT4           others            5.0    Checked Out
# 149        5.0           RT4          logtrip            NaN    Checked Out
#
#      revenue_generated  revenue_realized
# 137              38760             38760
# 139              45220             45220
# 143              35530             35530
# ...

# %%
df4 = pd.merge(df_new , df_new2_bookings , on="property_id")
df4.head(4)
# Out:
#    property_id check_in_date_x room_category_x  successful_bookings  capacity  \
# 0        19563       10-May-22             RT3                   15      29.0
# 1        19563       10-May-22             RT3                   15      29.0
# 2        19563       10-May-22             RT3                   15      29.0
# 3        19563       10-May-22             RT3                   15      29.0
#
#    occ_pct room_class property_name  category       city  ... booking_date  \
# 0    51.72    Premium  Atliq Palace  Business  Bangalore  ...     30-04-22
# 1    51.72    Premium  Atliq Palace  Business  Bangalore  ...     2/5/2022
# 2    51.72    Premium  Atliq Palace  Business  Bangalore  ...     29-04-22
# 3    51.72    Premium  Atliq Palace  Business  Bangalore  ...     1/5/2022
#
#   check_in_date_y checkout_date  no_guests room_category_y booking_platform  \
# 0        1/5/2022      3/5/2022        4.0             RT4          logtrip
# ...

# %%
df4.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Aug-22      24441562
# Jul 22    4895819984
# Jun 22    4673282712
# May 22    4895819984
# Name: revenue_realized, dtype: int64
